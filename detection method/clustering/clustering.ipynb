# %% [markdown]
# - K-Means Clustering:
#
#     - Calculate features for each time series (discussed in the next point) and use K-Means clustering to group similar patterns.
#
# - Hierarchical Clustering:
#
#     - Cluster time series hierarchically based on similarity.
#
# __Things to Consider__
#
# - Here we take the subtraces (50 events)
# - Every subtrace that contains any anomaly is labelled as anomalous

# %%
import json
import os
import numpy as np
import pandas as pd

def load_sample(file_path):
        data = np.load(file_path, allow_pickle=False)
        return data

# %%
############ configuration ################
############################################

code = 'theft_protection'       ### application (code)
behaviour = 'faulty_data'            ### normal, faulty_data
thread_typ = 'single'           ### single, multi
version = 2.2                     ### format of data collection
sub_len = 50

base_dir = '../trace_data' ### can be replaced with 'csv', 'exe_plot', 'histogram'
log_path = base_dir+f'/{code}/{thread_typ}_thread/version_{version}/{behaviour}'

#### subtraces
subtrace_path = f"../data-subtraces/version_{version}/{behaviour}/subtraces/{sub_len}"
print(log_path)
# Out:
# ../trace_data/theft_protection/single_thread/version_2.2/faulty_data

# %%
### get files from subtraces
# all_subtraces = os.listdir(subtrace_path)
# all_subtraces.remove('.DS_Store')

anomalies_files = os.listdir(subtrace_path+'/anomalies')
if '.DS_Store' in anomalies_files:
    anomalies_files.remove('.DS_Store')

normal_files = os.listdir(subtrace_path+'/normal')
if '.DS_Store' in normal_files:
    normal_files.remove('.DS_Store')

anomalies_path = [subtrace_path+'/anomalies/'+file for file in anomalies_files]
normal_path = [subtrace_path+'/normal/'+file for file in normal_files]

# %%
anomalies_path
# Out:
# ['../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_5150_5200.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_5800_5850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3650_3700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_7700_7750.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_7900_7950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8850_8900.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9950_10000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_6250_6300.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3800_3850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_5650_5700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_3600_3650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_5100_5150.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_9400_9450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_6950_7000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_4400_4450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_5750_5800.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_6200_6250.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_7900_7950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8800_8850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3850_3900.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_5600_5650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3100_3150.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9750_9800.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_2650_2700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_6900_6950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6700_6750.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_1500_1550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_8450_8500.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_3400_3450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9850_9900.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_1200_1250.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_4850_4900.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_4650_4700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_4350_4400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_9100_9150.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_3450_3500.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9800_9850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_6700_6750.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_4600_4650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_4800_4850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_1250_1300.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_2650_2700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_2350_2400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3400_3450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8450_8500.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3300_3350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9350_9400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_100_150.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_3450_3500.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_1200_1250.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_600_650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3450_3500.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8400_8450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_10000_10050.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_5300_5350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8300_8350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_3400_3450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_8600_8650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_10150_10200.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8350_8400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_7000_7050.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_8100_8150.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_2450_2500.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_8650_8700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_3150_3200.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_2300_2350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_150_200.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9400_9450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6500_6550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6550_6600.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9300_9350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_2400_2450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_3100_3150.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_7950_8000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3350_3400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_1150_1200.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6400_6450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_4950_5000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6300_6350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9200_9250.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_5900_5950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_2500_2550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_3950_4000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_7750_7800.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_4550_4600.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_1350_1400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6450_6500.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_9250_9300.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_10050_10100.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_4500_4550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_3550_3600.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_1300_1350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8950_9000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8200_8250.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_5200_5250.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_3500_3550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_1400_1450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_10100_10150.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3500_3550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8250_8300.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_5250_5300.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_8950_9000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_4000_4050.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6350_6400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6650_6700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_6850_6900.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_7400_7450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_8500_8550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_9000_9050.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_6750_6800.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_4900_4950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_6600_6650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_200_250.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_8550_8600.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_10000_10050.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_4050_4100.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_6800_6850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6600_6650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_6750_6800.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_3500_3550.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_9050_9100.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_700_750.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_300_350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_6350_6400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_4000_4050.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_7850_7900.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_7650_7700.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_1800_1850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_1750_1800.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_6400_6450.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_5700_5750.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_6300_6350.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_7800_7850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_8900_8950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_1350_1400.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_250_300.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3950_4000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_5050_5100.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_5950_6000.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_7600_7650.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_8900_8950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace2-bitflip_7800_7850.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_7750_7800.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace3-sensor_2550_2600.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_3900_3950.npy',
#  '../data-subtraces/version_2.2/faulty_data/subtraces/50/anomalies/trace1-comm_5000_5050.npy']

# %% [markdown]
# ## k-means clustering

# %% [markdown]
# _Feature Extraction for K-Means Clustering:_
#
# __Execution Intervals:__
#
# - Calculate the mean, standard deviation, and other statistical measures of the time differences between consecutive executions for each variable within a subtrace.
#
# __Event Frequency:__
#
# - Count the frequency of each variable within the subtrace.
#
# __Sequence Patterns:__
#
# - Convert the subtrace into a sequence of events and use techniques like sequence embedding to represent these sequences numerically.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

def extract_features(subtrace):
    timestamps = [int(timestamp) for _, timestamp in subtrace]
    # print(timestamps)
    execution_intervals = np.diff(timestamps)
    
    mean_execution_interval = np.mean(execution_intervals)
    std_execution_interval = np.std(execution_intervals)

    # Count occurrences of unique variables in the subtrace
    unique_variables, variable_counts = np.unique(subtrace[:, 0], return_counts=True)
    event_frequency = dict(zip(unique_variables, variable_counts))

    # Additional features can be added based on your specific requirements

    return [mean_execution_interval, std_execution_interval] + list(event_frequency.values())

# %%
normal_labels = [0]*len(normal_files)
anomalies_labels = [1]*len(anomalies_files)

# #### split the normal data in 80:20 ratio
# X_train, X_test, y_train, y_test = train_test_split(normal_files, normal_labels, test_size=0.2, random_state=42)

# #### combine the train and test data
# X_test += anomalies_files
# y_test += anomalies_labels

# #### shuffle test files
# X_test, y_test = shuffle(X_test, y_test, random_state=42)

all_files = normal_path + anomalies_path
all_labels = normal_labels + anomalies_labels

#### shuffle all files
all_files, all_labels = shuffle(all_files, all_labels, random_state=42)

# %%
# Extract features for each subtrace
all_features = []
for sub_path in all_files:
    subtrace = np.load(sub_path, allow_pickle=False)
    # print(subtrace)

    features = extract_features(subtrace)
    all_features.append(features)

# %%
all_features
# Out:
# [[232.7, 416.8575895914575, 2, 12, 11, 11, 2, 2, 11],
#  [150.02, 350.28362736502544, 2, 7, 8, 7, 7, 7, 2, 1, 2, 8],
#  [212.12, 402.9254839297212, 3, 11, 10, 10, 3, 3, 11],
#  [191.28, 387.41765783195785, 2, 3, 3, 9, 9, 9, 2, 3, 2, 9],
#  [149.88, 350.33998572814954, 2, 7, 7, 7, 7, 7, 2, 2, 2, 8],
#  [211.6, 403.32855093583447, 2, 2, 2, 9, 10, 10, 2, 2, 2, 10],
#  [211.02, 402.919817829801, 2, 2, 2, 10, 10, 10, 2, 2, 2, 9],
#  [211.34, 403.0137769357271, 2, 2, 2, 10, 10, 10, 2, 2, 2, 9],
#  [170.04, 370.0491837580513, 1, 8, 7, 8, 8, 8, 1, 2, 1, 7],
#  [191.7, 387.2255802500656, 2, 2, 2, 10, 9, 10, 2, 2, 2, 10],
#  [190.96, 387.0516223968064, 2, 2, 2, 10, 9, 10, 2, 2, 2, 10],
#  [190
 2, 2, 2, 9, 10, 10, 2, 2, 2, 10],
#  [211.02, 403.1621753091428, 2, 2, 2, 9, 10, 10, 2, 2, 2, 10],
#  [191.12, 387.23727299938474, 2, 2, 2, 10, 9, 10, 2, 2, 2, 10],
#  [191.18, 387.57449296877115, 2, 2, 2, 10, 9, 10, 2, 2, 2, 10],
#  [211.08, 403.23391920819364, 2, 2, 2, 9, 10, 10, 2, 2, 2, 10],
#  [192.62, 386.68275834332206, 3, 2, 2, 9, 9, 9, 3, 2, 3, 9],
#  [190.6, 387.316769582728, 2, 2, 2, 10, 10, 9, 2, 2, 2, 10],
#  [191.72, 387.2182351078007, 2, 2, 2, 10, 9, 10, 2, 3, 2, 9],
#  [232.72, 417.0399520429667, 2, 12, 11, 11, 2, 2, 11],
#  [212.84, 402.35389199062064, 2, 2, 2, 9, 10, 10, 2, 2, 2, 10],
#  [189.2391304347826, 380.6228410966179, 2, 2, 2, 9, 9, 8, 2, 2, 2, 9],
#  [212.26, 403.60752272473815, 2, 2, 2, 10, 10, 10, 2, 2, 2, 9],
#  [191.12, 386.97460588519243, 2, 2, 2, 10, 9, 10, 2, 2, 2, 10],
#  [191.72, 387.21704714539624, 2, 2, 2, 10, 9, 10, 2, 2, 2, 10],
#  [191.28, 387.46772975307243, 2, 2, 2, 10, 10, 9, 2, 2, 2, 10]]

# %%
# Convert the feature matrix to a numpy array
X = np.array(features)

# Normalize features (optional but can be beneficial for K-Means)
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# Fit K-Means model
num_clusters = 2  # Adjust based on your understanding of the data
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X_normalized)

# Get cluster assignments
cluster_assignments = kmeans.labels_

# Assume anomalous cluster is the one with fewer instances
anomalous_cluster = np.argmin(np.bincount(cluster_assignments))

# Label subtraces based on cluster assignments
# If a subtrace is assigned to the anomalous cluster, label it as anomalous
labels = ['Anomalous' if label == anomalous_cluster else 'Normal' for label in cluster_assignments]

# Print or use the labels as needed
for i, label in enumerate(labels):
    print(f"Subtrace {i+1}: {label}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 6
#       4 # Normalize features (optional but can be beneficial for K-Means)
#       5 scaler = StandardScaler()
# ----> 6 X_normalized = scaler.fit_transform(X)
#       8 # Fit K-Means model
#       9 num_clusters = 2  # Adjust based on your understanding of the data
#
# File ~/Documents/Seafile/work/Phd tasks/diagnosis tool/venv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/Documents/Seafile/work/Phd tasks/diagnosis tool/venv/lib/python3.10/site-packages/sklearn/base.py:916, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     912 # non-optimized default implementation; override when a better
#     913 # method is possible for a given clustering algorithm
#     914 if y is None:
#     915     # fit method of arity 1 (unsupervised transformation)
# --> 916     return self.fit(X, **fit_params).transform(X)
#     917 else:
#     918     # fit method of arity 2 (supervised transformation)
#     919     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Documents/Seafile/work/Phd tasks/diagnosis tool/venv/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:839, in StandardScaler.fit(self, X, y, sample_weight)
#     837 # Reset internal state before fitting
#     838 self._reset()
# --> 839 return self.partial_fit(X, y, sample_weight)
#
# File ~/Documents/Seafile/work/Phd tasks/diagnosis tool/venv/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/Seafile/work/Phd tasks/diagnosis tool/venv/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:875, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     843 """Online computation of mean and std on X for later scaling.
#     844
#     845 All of X is processed as a single batch. This is intended for cases
#    (...)
#     872     Fitted scaler.
#     873 """
#     874 first_call = not hasattr(self, "n_samples_seen_")
# --> 875 X = self._validate_data(
#     876     X,
#     877     accept_sparse=("csr", "csc"),
#     878     dtype=FLOAT_DTYPES,
#     879     force_all_finite="allow-nan",
#     880     reset=first_call,
#     881 )
#     882 n_features = X.shape[1]
#     884 if sample_weight is not None:
#
# File ~/Documents/Seafile/work/Phd tasks/diagnosis tool/venv/lib/python3.10/site-packages/sklearn/base.py:605, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     603         out = X, y
#     604 elif not no_val_X and no_val_y:
# --> 605     out = check_array(X, input_name="X", **check_params)
#     606 elif no_val_X and not no_val_y:
#     607     out = _check_y(y, **check_params)
#
# File ~/Documents/Seafile/work/Phd tasks/diagnosis tool/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:938, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     936     # If input is 1D raise error
#     937     if array.ndim == 1:
# --> 938         raise ValueError(
#     939             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     940             "Reshape your data either using array.reshape(-1, 1) if "
#     941             "your data has a single feature or array.reshape(1, -1) "
#     942             "if it contains a single sample.".format(array)
#     943         )
#     945 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     946     raise ValueError(
#     947         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     948         "Convert your data to numeric values explicitly instead."
#     949     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[191.28       387.46772975   2.           2.           2.
#   10.          10.           9.           2.           2.
#    2.          10.        ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ## hierarchical clustering

# %% [markdown]
# _Feature Extraction for Hierarchical Clustering:_
#
# __Temporal Patterns:__
#
# - Use the timestamps of events within the subtrace to capture temporal patterns. Features could include mean, standard deviation, and other statistical measures of timestamps.
#
# __Event Co-occurrence:__
#
# - Create a matrix indicating the co-occurrence of events within the subtrace.
#
# __Time Series Characteristics:__
#
# - Extract basic statistical features such as mean, variance, skewness, and kurtosis for the entire subtrace.

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import pdist, squareform
import numpy as np

def extract_features_for_hierarchical(subtrace):
    timestamps = [timestamp for _, timestamp in subtrace]
    execution_intervals = np.diff(timestamps)

    mean_execution_interval = np.mean(execution_intervals)
    std_execution_interval = np.std(execution_intervals)

    event_frequency = {var: subtrace.count([var, _]) for var, _ in subtrace}

    # Additional features can be added based on your specific requirements

    return [mean_execution_interval, std_execution_interval] + list(event_frequency.values())

def calculate_event_co_occurrence_matrix(subtrace):
    unique_vars = list(set(var for var, _ in subtrace))
    co_occurrence_matrix = np.zeros((len(unique_vars), len(unique_vars)))

    for i, var1 in enumerate(unique_vars):
        for j, var2 in enumerate(unique_vars):
            co_occurrence_matrix[i, j] = sum(1 for x, _ in subtrace if x == var1 and [var2, _] in subtrace)

    return co_occurrence_matrix

def hierarchical_clustering_features(subtrace):
    features = extract_features_for_hierarchical(subtrace)
    co_occurrence_matrix = calculate_event_co_occurrence_matrix(subtrace)

    # Flatten the upper triangular part of the co-occurrence matrix (excluding the diagonal)
    flattened_co_occurrence = squareform(pdist(co_occurrence_matrix, 'euclidean'))

    # Concatenate features with flattened co-occurrence matrix
    hierarchical_features = features + list(flattened_co_occurrence)

    return hierarchical_features

# %%
# Example subtraces (replace with your own data)
subtraces = [
    [['var1', 100], ['var2', 110], ['var1', 120]],
    [['var2', 110], ['var1', 120], ['var2', 130]],
    [['var1', 140], ['var2', 150], ['var1', 160]],
    # ... more subtraces
]

# Extract features for Hierarchical clustering
# Extract features for each subtrace
features_hierarchical = [extract_features_for_hierarchical(subtrace) for subtrace in subtraces]
print("Hierarchical Features:", features_hierarchical)
# Out:
# Hierarchical Features: [10.0, 0.0, 1, 1, array([0.        , 3.60555128]), array([3.60555128, 0.        ])]

# %%
# Extract features for each subtrace
features_hierarchical = [extract_features_for_hierarchical(subtrace) for subtrace in subtraces]

# Calculate event co-occurrence matrix
co_occurrence_matrices = [calculate_event_co_occurrence_matrix(subtrace) for subtrace in subtraces]

# Flatten the upper triangular part of the co-occurrence matrices (excluding the diagonal)
flattened_co_occurrence = [squareform(pdist(matrix, 'euclidean')) for matrix in co_occurrence_matrices]

# Concatenate features with flattened co-occurrence matrices
hierarchical_features = np.concatenate([features_hierarchical, flattened_co_occurrence], axis=1)

# Normalize features (optional but can be beneficial for Hierarchical Clustering)
scaler = StandardScaler()
hierarchical_features_normalized = scaler.fit_transform(hierarchical_features)

# Fit Hierarchical Clustering model
num_clusters = 2  # Adjust based on your understanding of the data
hierarchical = AgglomerativeClustering(n_clusters=num_clusters)
hierarchical_assignments = hierarchical.fit_predict(hierarchical_features_normalized)

# Assume anomalous cluster is the one with fewer instances
anomalous_cluster_hierarchical = np.argmin(np.bincount(hierarchical_assignments))

# Label subtraces based on cluster assignments
# If a subtrace is assigned to the anomalous cluster, label it as anomalous
labels_hierarchical = ['Anomalous' if label == anomalous_cluster_hierarchical else 'Normal' for label in hierarchical_assignments]

# Print or use the labels as needed
for i, label in enumerate(labels_hierarchical):
    print(f"Subtrace {i+1}: {label}")

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def evaluate_clustering(labels_true, labels_pred):
    # Convert labels to binary (1 for anomalous, 0 for normal)
    labels_true_binary = np.array([1 if label == 'Anomalous' else 0 for label in labels_true])
    labels_pred_binary = np.array([1 if label == 'Anomalous' else 0 for label in labels_pred])

    # Calculate precision, recall, and F1-score
    precision = precision_score(labels_true_binary, labels_pred_binary)
    recall = recall_score(labels_true_binary, labels_pred_binary)
    f1 = f1_score(labels_true_binary, labels_pred_binary)

    return precision, recall, f1

# %%
# Example: Ground truth labels and predicted labels
labels_true = ['Normal', 'Anomalous', 'Normal', 'Normal', 'Anomalous']
labels_pred_kmeans = ['Normal', 'Anomalous', 'Normal', 'Normal', 'Anomalous']  # Replace with your predicted labels for K-Means
labels_pred_hierarchical = ['Normal', 'Anomalous', 'Normal', 'Normal', 'Anomalous']  # Replace with your predicted labels for Hierarchical

# %%
# Evaluate K-Means model
precision_kmeans, recall_kmeans, f1_kmeans = evaluate_clustering(labels_true, labels_pred_kmeans)
print("K-Means Model:")
print(f"Precision: {precision_kmeans:.2f}")
print(f"Recall: {recall_kmeans:.2f}")
print(f"F1-score: {f1_kmeans:.2f}")
print()

# %%
# Evaluate Hierarchical Clustering model
precision_hierarchical, recall_hierarchical, f1_hierarchical = evaluate_clustering(labels_true, labels_pred_hierarchical)
print("Hierarchical Clustering Model:")
print(f"Precision: {precision_hierarchical:.2f}")
print(f"Recall: {recall_hierarchical:.2f}")
print(f"F1-score: {f1_hierarchical:.2f}")
